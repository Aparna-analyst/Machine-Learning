# %% [markdown]
# ##**Import necessary libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ##**Load the dataset**

# %%
filepath="/content/cars.csv"
df=pd.read_csv(filepath)
df.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# 1                       True                                           6
# 2                       True                                           6
# 3                       True                                           6
# 4                       True                                           6
#
#   Engine Information.Transmission  Fuel Information.City mpg  \
# 0  6 Speed Automatic Select Shift                         18
# 1  6 Speed Automatic Select Shift                         22
# 2                  6 Speed Manual                         21
# 3  6 Speed Automatic Select Shift                         21
# 4  6 Speed Automatic Select Shift                         21
#
#   Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                   Gasoline                            25
# 1                   Gasoline                            28
# 2                   Gasoline                            30
# 3                   Gasoline                            28
# 4                   Gasoline                            28
#
#   Identification.Classification           Identification.ID  \
# 0        Automatic transmission            2009 Audi A3 3.2
# 1        Automatic transmission       2009 Audi A3 2.0 T AT
# 2           Manual transmission          2009 Audi A3 2.0 T
# 3        Automatic transmission  2009 Audi A3 2.0 T Quattro
# 4        Automatic transmission  2009 Audi A3 2.0 T Quattro
#
#   Identification.Make Identification.Model Year  Identification.Year  \
# 0                Audi              2009 Audi A3                 2009
# 1                Audi              2009 Audi A3                 2009
# 2                Audi              2009 Audi A3                 2009
# 3                Audi              2009 Audi A3                 2009
# 4                Audi              2009 Audi A3                 2009
#
#    Engine Information.Engine Statistics.Horsepower  \
# 0                                              250
# 1                                              200
# 2                                              200
# 3                                              200
# 4                                              200
#
#    Engine Information.Engine Statistics.Torque
# 0                                          236
# 1                                          207
# 2                                          207
# 3                                          207
# 4                                          207

# %% [markdown]
# ###**Plots**

# %%
#scatter plot to show linear relationship
sns.scatterplot(x=df['Fuel Information.City mpg'],y=df['Fuel Information.Highway mpg'])
plt.show()

# %%
sns.scatterplot(x=df['Engine Information.Engine Statistics.Torque'],y=df['Fuel Information.Highway mpg'])
plt.show()

# %%
sns.scatterplot(x=df['Identification.Model Year'],y=df['Fuel Information.Highway mpg'])
plt.show()

# %%
sns.scatterplot(x=df['Engine Information.Engine Type'],y=df['Fuel Information.Highway mpg'])
plt.show()

# %%
sns.scatterplot(x=df['Fuel Information.Fuel Type'],y=df['Fuel Information.Highway mpg'])
plt.show()

# %% [markdown]
# ##**Describe the data**

# %%
df.shape
# Out:
# (5076, 18)

# %%
df.describe()
# Out:
#        Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# count        5076.000000        5076.000000       5076.000000
# mean          145.632191         127.825847        144.012411
# std            62.125026          77.358295         79.925899
# min             1.000000           2.000000          1.000000
# 25%           104.000000          60.000000         62.000000
# 50%           152.000000         128.000000        158.000000
# 75%           193.000000         198.000000        219.000000
# max           255.000000         255.000000        254.000000
#
#        Engine Information.Number of Forward Gears  Fuel Information.City mpg  \
# count                                 5076.000000                5076.000000
# mean                                     5.519110                  17.275808
# std                                      0.845637                   4.479485
# min                                      4.000000                   8.000000
# 25%                                      5.000000                  14.000000
# 50%                                      6.000000                  17.000000
# 75%                                      6.000000                  20.000000
# max                                      8.000000                  38.000000
#
#        Fuel Information.Highway mpg  Identification.Year  \
# count                   5076.000000          5076.000000
# mean                      24.125493          2010.867612
# std                        6.488293             0.782951
# min                       11.000000          2009.000000
# 25%                       20.000000          2010.000000
# 50%                       24.000000          2011.000000
# 75%                       28.000000          2011.000000
# max                      223.000000          2012.000000
#
#        Engine Information.Engine Statistics.Horsepower  \
# count                                      5076.000000
# mean                                        270.499409
# std                                          95.293537
# min                                         100.000000
# 25%                                         190.000000
# 50%                                         266.000000
# 75%                                         317.000000
# max                                         638.000000
#
#        Engine Information.Engine Statistics.Torque
# count                                  5076.000000
# mean                                    272.707250
# std                                     100.123328
# min                                      98.000000
# 25%                                     187.000000
# 50%                                     260.000000
# 75%                                     335.000000
# max                                     774.000000

# %%
#dimension of the dataset
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# Dimensions.Height                                   int64
# Dimensions.Length                                   int64
# Dimensions.Width                                    int64
# Engine Information.Driveline                       object
# Engine Information.Engine Type                     object
# Engine Information.Hybrid                            bool
# Engine Information.Number of Forward Gears          int64
# Engine Information.Transmission                    object
# Fuel Information.City mpg                           int64
# Fuel Information.Fuel Type                         object
# Fuel Information.Highway mpg                        int64
# Identification.Classification                      object
# Identification.ID                                  object
# Identification.Make                                object
# Identification.Model Year                          object
# Identification.Year                                 int64
# Engine Information.Engine Statistics.Horsepower     int64
# Engine Information.Engine Statistics.Torque         int64
# dtype: object

# %%
#list numerical variables
numerical_cols=df.select_dtypes(include=[np.number]).columns
numerical_cols
# Out:
# Index(['Dimensions.Height', 'Dimensions.Length', 'Dimensions.Width',
#        'Engine Information.Number of Forward Gears',
#        'Fuel Information.City mpg', 'Fuel Information.Highway mpg',
#        'Identification.Year',
#        'Engine Information.Engine Statistics.Horsepower',
#        'Engine Information.Engine Statistics.Torque'],
#       dtype='object')

# %%
#list categorical variable
categorical_variables=df.select_dtypes(include=['object']).columns
print(categorical_variables)
# Out:
# Index(['Engine Information.Driveline', 'Engine Information.Engine Type',
#        'Engine Information.Transmission', 'Fuel Information.Fuel Type',
#        'Identification.Classification', 'Identification.ID',
#        'Identification.Make', 'Identification.Model Year'],
#       dtype='object')

# %% [markdown]
# ##**Data cleaning**

# %%
#identify missing values
df.isnull().sum()
# Out:
# Dimensions.Height                                  0
# Dimensions.Length                                  0
# Dimensions.Width                                   0
# Engine Information.Driveline                       0
# Engine Information.Engine Type                     0
# Engine Information.Hybrid                          0
# Engine Information.Number of Forward Gears         0
# Engine Information.Transmission                    0
# Fuel Information.City mpg                          0
# Fuel Information.Fuel Type                         0
# Fuel Information.Highway mpg                       0
# Identification.Classification                      0
# Identification.ID                                  0
# Identification.Make                                0
# Identification.Model Year                          0
# Identification.Year                                0
# Engine Information.Engine Statistics.Horsepower    0
# Engine Information.Engine Statistics.Torque        0
# dtype: int64

# %%
#identify duplicated values
df.duplicated().sum()
# Out:
# 18

# %%
df.drop_duplicates(inplace=True)
print(df.shape)
# Out:
# (5058, 18)

# %% [markdown]
# ##**Handle Outliers**

# %%
# Check for outliers in numerical columns
for col in numerical_cols:
    # Example using IQR method for outlier detection
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
print(df.shape)
# Out:
# (4794, 18)

# %% [markdown]
# ##**Handle Categorical variables**

# %%
#Handle categorical variables
df.drop(['Identification.ID'],axis=1,inplace=True)

# %%
# Assuming the target variable is 'Fuel Information.Highway mpg'
target = 'Fuel Information.Highway mpg'

# Columns to target encode
target_encoding_cols = ['Identification.Make', 'Identification.Model Year', 'Engine Information.Engine Type','Engine Information.Driveline']

# Perform target encoding
for col in target_encoding_cols:
    # Calculate the mean target value for each category
    target_mean = df.groupby(col)[target].mean()
    # Map the mean to each category in the dataset
    df[col + '_encoded'] = df[col].map(target_mean)

# Display the first few rows to inspect the result
df[[col + '_encoded' for col in target_encoding_cols]].head()
# Out:
#    Identification.Make_encoded  Identification.Model Year_encoded  \
# 0                    25.086207                              27.75
# 1                    25.086207                              27.75
# 2                    25.086207                              27.75
# 3                    25.086207                              27.75
# 5                    25.086207                              26.50
#
#    Engine Information.Engine Type_encoded  \
# 0                               25.000000
# 1                               29.333333
# 2                               29.333333
# 3                               29.333333
# 5                               26.500000
#
#    Engine Information.Driveline_encoded
# 0                             23.750993
# 1                             29.482668
# 2                             29.482668
# 3                             23.750993
# 5                             23.750993

# %%
df.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 5                 91                 17                62
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 5              All-wheel drive         Audi 3.2L 6 cylinder 265hp 243 ft-lbs
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# 1                       True                                           6
# 2                       True                                           6
# 3                       True                                           6
# 5                       True                                           6
#
#   Engine Information.Transmission  Fuel Information.City mpg  \
# 0  6 Speed Automatic Select Shift                         18
# 1  6 Speed Automatic Select Shift                         22
# 2                  6 Speed Manual                         21
# 3  6 Speed Automatic Select Shift                         21
# 5                  6 Speed Manual                         16
#
#   Fuel Information.Fuel Type  ...  Identification.Classification  \
# 0                   Gasoline  ...         Automatic transmission
# 1                   Gasoline  ...         Automatic transmission
# 2                   Gasoline  ...            Manual transmission
# 3                   Gasoline  ...         Automatic transmission
# 5                   Gasoline  ...            Manual transmission
#
#   Identification.Make Identification.Model Year Identification.Year  \
# 0                Audi              2009 Audi A3                2009
# 1                Audi              2009 Audi A3                2009
# 2                Audi              2009 Audi A3                2009
# 3                Audi              2009 Audi A3                2009
# 5                Audi              2009 Audi A5                2009
#
#    Engine Information.Engine Statistics.Horsepower  \
# 0                                              250
# 1                                              200
# 2                                              200
# 3                                              200
# 5                                              265
#
#    Engine Information.Engine Statistics.Torque  Identification.Make_encoded  \
# 0                                          236                    25.086207
# 1                                          207                    25.086207
# 2                                          207                    25.086207
# 3                                          207                    25.086207
# 5                                          243                    25.086207
#
#    Identification.Model Year_encoded  Engine Information.Engine Type_encoded  \
# 0                              27.75                               25.000000
# 1                              27.75                               29.333333
# 2                              27.75                               29.333333
# 3                              27.75                               29.333333
# 5                              26.50                               26.500000
#
#    Engine Information.Driveline_encoded
# 0                             23.750993
# 1                             29.482668
# 2                             29.482668
# 3                             23.750993
# 5                             23.750993
#
# [5 rows x 21 columns]

# %%
df.drop(target_encoding_cols,axis=1,inplace=True)

# %%
df.shape
# Out:
# (4794, 17)

# %%
# Columns for One-Hot Encoding
one_hot_encoding_cols = [
    'Fuel Information.Fuel Type',
    'Engine Information.Transmission',
    'Identification.Classification'
]

# Perform One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=one_hot_encoding_cols, drop_first=True)

df_encoded.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 5                 91                 17                62
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# 1                       True                                           6
# 2                       True                                           6
# 3                       True                                           6
# 5                       True                                           6
#
#    Fuel Information.City mpg  Fuel Information.Highway mpg  \
# 0                         18                            25
# 1                         22                            28
# 2                         21                            30
# 3                         21                            28
# 5                         16                            27
#
#    Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 0                 2009                                              250
# 1                 2009                                              200
# 2                 2009                                              200
# 3                 2009                                              200
# 5                 2009                                              265
#
#    Engine Information.Engine Statistics.Torque  ...  \
# 0                                          236  ...
# 1                                          207  ...
# 2                                          207  ...
# 3                                          207  ...
# 5                                          243  ...
#
#    Engine Information.Transmission_4 Speed Automatic Select Shift  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Engine Information.Transmission_5 Speed Automatic  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Engine Information.Transmission_5 Speed Automatic Select Shift  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Engine Information.Transmission_5 Speed Manual  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 5                                           False
#
#    Engine Information.Transmission_6 Speed Automatic  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Engine Information.Transmission_6 Speed Automatic Select Shift  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 5                                              False
#
#    Engine Information.Transmission_6 Speed Manual  \
# 0                                           False
# 1                                           False
# 2                                            True
# 3                                           False
# 5                                            True
#
#    Engine Information.Transmission_7 Speed Automatic  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Engine Information.Transmission_7 Speed Automatic Select Shift  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Identification.Classification_Manual transmission
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 5                                               True
#
# [5 rows x 27 columns]

# %% [markdown]
# ##**Feature selection using RFE**

# %%
#feature scaling
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df_encoded[df_encoded.select_dtypes(include=[np.number]).columns]=scaler.fit_transform(df_encoded[df.select_dtypes(include=[np.number]).columns])
df_encoded.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0           0.545455           0.557312          0.794466
# 1           0.545455           0.557312          0.794466
# 2           0.545455           0.557312          0.794466
# 3           0.545455           0.557312          0.794466
# 5           0.351779           0.059289          0.241107
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                    0.666667
# 1                       True                                    0.666667
# 2                       True                                    0.666667
# 3                       True                                    0.666667
# 5                       True                                    0.666667
#
#    Fuel Information.City mpg  Fuel Information.Highway mpg  \
# 0                   0.476190                      0.482759
# 1                   0.666667                      0.586207
# 2                   0.619048                      0.655172
# 3                   0.619048                      0.586207
# 5                   0.380952                      0.551724
#
#    Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 0                  0.0                                           0.3750
# 1                  0.0                                           0.2500
# 2                  0.0                                           0.2500
# 3                  0.0                                           0.2500
# 5                  0.0                                           0.4125
#
#    Engine Information.Engine Statistics.Torque  ...  \
# 0                                     0.318707  ...
# 1                                     0.251732  ...
# 2                                     0.251732  ...
# 3                                     0.251732  ...
# 5                                     0.334873  ...
#
#    Engine Information.Transmission_4 Speed Automatic Select Shift  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Engine Information.Transmission_5 Speed Automatic  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Engine Information.Transmission_5 Speed Automatic Select Shift  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Engine Information.Transmission_5 Speed Manual  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 5                                           False
#
#    Engine Information.Transmission_6 Speed Automatic  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Engine Information.Transmission_6 Speed Automatic Select Shift  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 5                                              False
#
#    Engine Information.Transmission_6 Speed Manual  \
# 0                                           False
# 1                                           False
# 2                                            True
# 3                                           False
# 5                                            True
#
#    Engine Information.Transmission_7 Speed Automatic  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Engine Information.Transmission_7 Speed Automatic Select Shift  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 5                                              False
#
#    Identification.Classification_Manual transmission
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 5                                               True
#
# [5 rows x 27 columns]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import Ridge

X = df_encoded.drop('Fuel Information.Highway mpg', axis=1)
y = df_encoded['Fuel Information.Highway mpg']

ridge = Ridge()
rfe = RFE(ridge, n_features_to_select=5)  # Select top 5 features
rfe.fit(X, y)

selected_features = X.columns[rfe.support_]
print("Selected Features by RFE:", selected_features)
# Out:
# Selected Features by RFE: Index(['Fuel Information.City mpg',
#        'Engine Information.Engine Statistics.Torque',
#        'Identification.Model Year_encoded',
#        'Engine Information.Engine Type_encoded',
#        'Fuel Information.Fuel Type_E85'],
#       dtype='object')

# %%
#convert boolean column to numeric
bool_cols = df_encoded.select_dtypes(include=['bool']).columns
df_encoded[bool_cols] = df_encoded[bool_cols].astype(int)

# %%
#vif
from statsmodels.stats.outliers_influence import variance_inflation_factor
selected_features = ['Fuel Information.City mpg', 'Identification.Model Year_encoded',
       'Fuel Information.Fuel Type_Diesel fuel',
       'Fuel Information.Fuel Type_E85',
       'Fuel Information.Fuel Type_Gasoline']

X = df_encoded[selected_features]

# Create a DataFrame to store VIF values
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#                                   Feature        VIF
# 0               Fuel Information.City mpg  37.727879
# 1       Identification.Model Year_encoded  28.532018
# 2  Fuel Information.Fuel Type_Diesel fuel   1.026109
# 3          Fuel Information.Fuel Type_E85   1.115832
# 4     Fuel Information.Fuel Type_Gasoline   7.338758

# %%
from sklearn.decomposition import PCA
# Extract features with high VIF
high_vif_features = ['Fuel Information.City mpg', 'Identification.Model Year_encoded']


# Apply PCA
pca = PCA(n_components=1)  # Reduce to a single component
X_pca = pca.fit_transform(df_encoded[high_vif_features])

# Create a new column in the DataFrame for the PCA component
df_encoded['PCA_Fuel_ModelYear'] = X_pca

# Drop the original correlated features
df_encoded = df_encoded.drop(columns=high_vif_features)

print("Transformed DataFrame with PCA feature added:")
df_encoded.head()
# Out:
# Transformed DataFrame with PCA feature added:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0           0.545455           0.557312          0.794466
# 1           0.545455           0.557312          0.794466
# 2           0.545455           0.557312          0.794466
# 3           0.545455           0.557312          0.794466
# 5           0.351779           0.059289          0.241107
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                          1                                    0.666667
# 1                          1                                    0.666667
# 2                          1                                    0.666667
# 3                          1                                    0.666667
# 5                          1                                    0.666667
#
#    Fuel Information.Highway mpg  Identification.Year  \
# 0                      0.482759                  0.0
# 1                      0.586207                  0.0
# 2                      0.655172                  0.0
# 3                      0.586207                  0.0
# 5                      0.551724                  0.0
#
#    Engine Information.Engine Statistics.Horsepower  \
# 0                                           0.3750
# 1                                           0.2500
# 2                                           0.2500
# 3                                           0.2500
# 5                                           0.4125
#
#    Engine Information.Engine Statistics.Torque  Identification.Make_encoded  \
# 0                                     0.318707                     0.489386
# 1                                     0.251732                     0.489386
# 2                                     0.251732                     0.489386
# 3                                     0.251732                     0.489386
# 5                                     0.334873                     0.489386
#
#    ...  Engine Information.Transmission_5 Speed Automatic  \
# 0  ...                                                  0
# 1  ...                                                  0
# 2  ...                                                  0
# 3  ...                                                  0
# 5  ...                                                  0
#
#    Engine Information.Transmission_5 Speed Automatic Select Shift  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 5                                                  0
#
#    Engine Information.Transmission_5 Speed Manual  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 5                                               0
#
#    Engine Information.Transmission_6 Speed Automatic  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 5                                                  0
#
#    Engine Information.Transmission_6 Speed Automatic Select Shift  \
# 0                                                  1
# 1                                                  1
# 2                                                  0
# 3                                                  1
# 5                                                  0
#
#    Engine Information.Transmission_6 Speed Manual  \
# 0                                               0
# 1                                               0
# 2                                               1
# 3                                               0
# 5                                               1
#
#    Engine Information.Transmission_7 Speed Automatic  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 5                                                  0
#
#    Engine Information.Transmission_7 Speed Automatic Select Shift  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 5                                                  0
#
#    Identification.Classification_Manual transmission  PCA_Fuel_ModelYear
# 0                                                  0            0.119822
# 1                                                  0            0.256002
# 2                                                  1            0.221957
# 3                                                  0            0.221957
# 5                                                  1            0.018907
#
# [5 rows x 26 columns]

# %%
#vif
from statsmodels.stats.outliers_influence import variance_inflation_factor
selected_features = ['PCA_Fuel_ModelYear',
       'Fuel Information.Fuel Type_Diesel fuel',
       'Fuel Information.Fuel Type_E85',
       'Fuel Information.Fuel Type_Gasoline']

X = df_encoded[selected_features]

# Create a DataFrame to store VIF values
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#                                   Feature       VIF
# 0                      PCA_Fuel_ModelYear  1.217203
# 1  Fuel Information.Fuel Type_Diesel fuel  1.000074
# 2          Fuel Information.Fuel Type_E85  1.196751
# 3     Fuel Information.Fuel Type_Gasoline  1.020379

# %% [markdown]
# ##**Model Training**

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df_encoded[selected_features],df_encoded[target],test_size=0.2,random_state=42)
x_train.shape,x_test.shape
# Out:
# ((3835, 4), (959, 4))

# %%
#create linear regression object and fit using train data
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##**Prediction**

# %%
#predict the model using test data
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([0.71444353, 0.30066851, 0.51062915, 0.24779666, 0.39963522,
#        0.42413767, 0.23807975, 0.20121338, 0.55448741, 0.29798249,
#        0.24716593, 0.44060167, 0.56771377, 0.28398893, 0.37063509,
#        0.87938805, 0.36636141, 0.52180163, 0.78377938, 0.4703811 ,
#        0.56185243, 0.34061342, 0.52037707, 0.25856242, 0.42564378,
#        0.69323822, 0.48709102, 0.31202459, 0.50360854, 0.72394783,
#        0.44566918, 0.44756137, 0.62327164, 0.19132315, 0.02633493,
#        0.83054596, 0.5133906 , 0.5346299 , 0.43046664, 0.79676352,
#        0.34490801, 0.6574611 , 0.56527138, 0.75750655, 0.44914903,
#        0.23576945, 0.51718982, 0.28009393, 0.26236125, 0.38140084,
#        0.55679214, 0.23564764, 0.33517935, 0.62264091, 0.0818928 ,
#        0.46642706, 0.27919421, 0.80922907, 0.64787599, 0.28398893,
#        0.49854103, 0.1073637 , 0.71619429, 0.25858918, 0.29004565,
#        0.30567512, 0.52180163, 0.72394783, 0.48448724, 0.51404809,
#        0.30921588, 0.30666887, 0.51404809, 0.66252861, 0.31845118,
#        0.61377457, 0.41369089, 0.61551811, 0.03630686, 0.07913559,
#        0.26182669, 0.33977959, 0.69323822, 0.4320543 , 0.42791012,
#        0.46276391, 0.69671807, 0.37633333, 0.46642706, 0.07334544,
#        0.08372438, 0.22313171, 0.22313171, 0.51062915, 0.68133281,
#        0.28075142, 0.63529886, 0.65113213, 0.74611007, 0.40989206,
#        0.52259546, 0.30921588, 0.3676051 , 0.33517935, 0.31845118,
#        0.24590447, 0.28253604, 0.62247781, 0.46886917, 0.12456872,
#        0.11451868, 0.50208178, 0.32405181, 0.13161341, 0.3921666 ,
#        0.45159113, 0.42791012, 0.74372858, 0.53193665, 0.46435157,
#        0.25196445, 0.83317137, 0.57626114, 0.42564378, 0.6104506 ,
#        0.67278545, 0.27919421, 0.44273851, 0.45262888, 0.44914903,
#        0.47131127, 0.7796688 , 0.4120289 , 0.55226732, 0.30567512,
#        0.52196473, 0.49502758, 0.26414795, 0.34061342, 0.57198746,
#        0.19382646, 0.38359248, 0.49329021, 0.2863102 , 0.33517935,
#        0.42791012, 0.82810386, 0.25858918, 0.48413232, 0.19132315,
#        0.43046664, 0.51807786, 0.06479807, 0.54253931, 0.52196473,
#        0.24327906, 0.45262888, 0.29798249, 0.06986559, 0.35860787,
#        0.85374595, 0.57626114, 0.60617691, 0.52766297, 0.58971291,
#        0.49188585, 0.488406  , 0.37441706, 0.14870814, 0.58971291,
#        0.27582025, 0.41369089, 0.42350694, 0.56050942, 0.29041167,
#        0.74104255, 0.26182669, 0.54982521, 0.63340667, 0.10129783,
#        0.50550073, 0.16751234, 0.5260144 , 0.44276654, 0.02098251,
#        0.49695337, 0.26414795, 0.39279733, 0.87938805, 0.44914903,
#        0.38131929, 0.42820784, 0.39786484, 0.43046664, 0.50122705,
#        0.26483078, 0.49695337, 0.56050942, 0.22111682, 0.51575757,
#        0.25365801, 0.42179746, 0.25793169, 0.26182669, 0.87938805,
#        0.29628894, 0.24779666, 0.60617691, 0.4780696 , 0.35982892,
#        0.80380478, 0.6316972 , 0.4013447 , 0.55678492, 0.61484609,
#        0.5447577 , 0.25793169, 0.3568984 , 0.05454124, 0.78548885,
#        0.51689722, 0.2884701 , 0.46276391, 0.80472057, 0.30567512,
#        0.61124443, 0.3193509 , 0.2884701 , 0.47131127, 0.13903833,
#        0.78599777, 0.84855663, 0.5017482 , 0.42791012, 0.57831643,
#        0.26024199, 0.42350694, 0.55742287, 0.31845118, 0.45342271,
#        0.06418755, 0.51404809, 0.30567512, 0.45262888, 0.62960062,
#        0.3206418 , 0.8702915 , 0.79739425, 0.1073637 , 0.43126047,
#        0.49573231, 0.41843942, 0.57467348, 0.31845118, 0.50550073,
#        0.42863536, 0.28269526, 0.40470274, 0.5447577 , 0.78377938,
#        0.10288253, 0.49402269, 0.50922523, 0.34784212, 0.51689722,
#        0.31428339, 0.69323822, 0.49980249, 0.49103141, 0.51689722,
#        0.21092118, 0.66480791, 0.45421654, 0.31301711, 0.32283075,
#        0.90313795, 0.68697015, 0.33575041, 0.5681814 , 0.24327906,
#        0.26483078, 0.43260348, 0.64543388, 0.2205063 , 0.6574611 ,
#        0.44066257, 0.45421654, 0.42564378, 0.47814916, 0.87071887,
#        0.32884797, 0.50202088, 0.24590447, 0.28450663, 0.2159175 ,
#        0.49917176, 0.55495363, 0.46624376, 0.9886116 , 0.40641221,
#        0.07049632, 0.73432647, 0.47308165, 0.42698679, 0.3216302 ,
#        0.68133281, 0.11687609, 0.52259546, 0.48333849, 0.45262888,
#        0.31845118, 0.64036637, 0.25522159, 0.49909021, 0.60617691,
#        0.73787446, 0.88097571, 0.26770011, 0.58286592])

# %% [markdown]
# ##**Evaluation**

# %%
#r2 score
r2_score(y_test,y_pred)
# Out:
# 0.9529478094270936

# %%
#residual plot to show normal distribution
sns.displot(y_test-y_pred,kde=True)
plt.xlabel('residual')
plt.ylabel('density')
plt.show()

# %%
#residual plot to show homoskedasticity
sns.residplot(x=y_pred,y=y_test-y_pred)
plt.xlabel('y_pred')
plt.ylabel('residual')
plt.show()
